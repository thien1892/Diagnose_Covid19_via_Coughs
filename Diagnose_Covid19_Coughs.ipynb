# %% [markdown]
# <a href="https://colab.research.google.com/github/thien1892/Diagnose_Covid19_via_Coughs/blob/main/Diagnose_Covid19_Coughs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Clone code from github

# %%
! git clone https://github.com/thien1892/Diagnose_Covid19_via_Coughs.git
# Out:
# Cloning into 'Diagnose_Covid19_via_Coughs'...
# remote: Enumerating objects: 229, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 229 (delta 37), reused 215 (delta 23), pack-reused 0
# Receiving objects: 100% (229/229), 46.52 MiB | 29.38 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
cd /content/Diagnose_Covid19_via_Coughs
# Out:
# /content/Diagnose_Covid19_via_Coughs

# %% [markdown]
# # 2. Example predict file audio

# %%
import sys
import os
sys.path.insert(1, 'modules/')
from example_feature import *
from example_file import make_acoustic_feat, mask_acoustic_feat
sys.path.insert(1, 'configs/')
from example_config import Config

# %%
path_file = 'data//example_aicv115m_final_private_test//private_test_audio_files//1b432e7b-cbbe-4f02-9cf1-e38067c68b30.wav'

# %%
# play file audio
import IPython
IPython.display.Audio(path_file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# file is cough or no_cough
mask_X = mask_acoustic_feat(path_file)
# extract features
X = make_acoustic_feat(path_file)

# %%
# load model
import joblib
model = joblib.load(str(Config.WEIGHT_PATH / "example_model_gg.h5"))

# %%
# predict
y_predict = model.predict_proba(X)
y_predict = np.where(mask_X == True, y_predict, 0)
y_predict[:,1]
# Out:
# array([0.00093968], dtype=float32)

# %% [markdown]
# # 3. Train

# %%
! chmod +x scripts/run_train.sh
! ./scripts/run_train.sh
# Out:
# 2021-09-23 06:55:42.410380: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-23 06:55:42.410454: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e43302bd1df8): /proc/driver/nvidia/version does not exist
# 2021-09-23 06:55:48.975416: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# AUC score:       0.5000

# %% [markdown]
# # 4. Submit

# %%
# !chmod +x scripts/run_submission.sh
# !./scripts/run_submission.sh
# Out:
# 2021-09-23 07:04:24.964957: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-23 07:04:24.965013: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e43302bd1df8): /proc/driver/nvidia/version does not exist
# 2021-09-23 07:04:31.062158: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
